# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
cancer = pd.read_csv('../data/data_cancer.csv')

# %%
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Cancer Classification Report
#
# ## Evaluation Metrics
#
# ### Custom KNN
#
# - Accuracy: 0.9561
# - Precision: 0.9773
# - Recall: 0.9149
# - F1 Score: 0.9451
# - Training Time: 0.0024
#
# ### Custom NaiveBayes
#
# - Accuracy: 0.9298
# - Precision: 0.9149
# - Recall: 0.9149
# - F1 Score: 0.9149
# - Training Time: 0.0020
#
# ### Logistic Regression
#
# - Accuracy: 0.9561
# - Precision: 1.0000
# - Recall: 0.8936
# - F1 Score: 0.9438
# - Training Time: 0.0062
#
# ### Decision Tree
#
# - Accuracy: 0.9211
# - Precision: 0.8800
# - Recall: 0.9362
# - F1 Score: 0.9072
# - Training Time: 0.0030
#
# ### Random Forest
#
# - Accuracy: 0.9649
# - Precision: 0.9388
# - Recall: 0.9787
# - F1 Score: 0.9583
# - Training Time: 0.0154
#
# ### SVM
#
# - Accuracy: 0.9474
# - Precision: 0.9556
# - Recall: 0.9149
# - F1 Score: 0.9348
# - Training Time: 0.0086
#
# ### Naive Bayes
#
# - Accuracy: 0.9298
# - Precision: 0.9149
# - Recall: 0.9149
# - F1 Score: 0.9149
# - Training Time: 0.0021
#
# ### KNN
#
# - Accuracy: 0.9649
# - Precision: 0.9574
# - Recall: 0.9574
# - F1 Score: 0.9574
# - Training Time: 0.0020
#
# ### AdaBoost
#
# - Accuracy: 0.9561
# - Precision: 0.9773
# - Recall: 0.9149
# - F1 Score: 0.9451
# - Training Time: 0.0286
#
# ### Gradient Boosting
#
# - Accuracy: 0.9825
# - Precision: 0.9787
# - Recall: 0.9787
# - F1 Score: 0.9787
# - Training Time: 0.0234
#
# ### XGBoost
#
# - Accuracy: 0.9561
# - Precision: 0.9565
# - Recall: 0.9362
# - F1 Score: 0.9462
# - Training Time: 0.0138
#
# ## Cross-Validation Scores
#
# - Custom KNN: 0.9491 (+/- 0.0380)
# - Custom NaiveBayes: 0.9332 (+/- 0.0291)
# - Logistic Regression: 0.9367 (+/- 0.0274)
# - Decision Tree: 0.9350 (+/- 0.0222)
# - Random Forest: 0.9404 (+/- 0.0344)
# - SVM: 0.9613 (+/- 0.0189)
# - Naive Bayes: 0.9315 (+/- 0.0228)
# - KNN: 0.9596 (+/- 0.0360)
# - AdaBoost: 0.9473 (+/- 0.0222)
# - Gradient Boosting: 0.9404 (+/- 0.0353)
# - XGBoost: 0.9561 (+/- 0.0335)
#
# ## Classification Reports
#
# ### Best Params for Custom KNN model
#
# - {'feature_selection__k': 8, 'pca__n_components': 5}
#
# ### ROC Curve
#
# ### Custom KNN
#
# ![ROC Curve for Custom KNN](../reports/figures/roc_curve_Custom_KNN.png)
#
# ### Precision-Recall Curve
#
# ### Custom KNN
#
# ![Precision-Recall Curve for Custom KNN](../reports/figures/precision_recall_curve_Custom_KNN.png)
#
# ### Best Params for Custom NaiveBayes model
#
# - {'feature_selection__k': 7, 'pca__n_components': 3}
#
# ### ROC Curve
#
# ### Custom NaiveBayes
#
# ![ROC Curve for Custom NaiveBayes](../reports/figures/roc_curve_Custom_NaiveBayes.png)
#
# ### Precision-Recall Curve
#
# ### Custom NaiveBayes
#
# ![Precision-Recall Curve for Custom NaiveBayes](../reports/figures/precision_recall_curve_Custom_NaiveBayes.png)
#
# ### Best Params for Logistic Regression model
#
# - {'classifier__C': 0.02, 'classifier__penalty': 'l2', 'feature_selection__k': 10, 'pca__n_components': 4}
#
# ### ROC Curve
#
# ### Logistic Regression
#
# ![ROC Curve for Logistic Regression](../reports/figures/roc_curve_Logistic_Regression.png)
#
# ### Precision-Recall Curve
#
# ### Logistic Regression
#
# ![Precision-Recall Curve for Logistic Regression](../reports/figures/precision_recall_curve_Logistic_Regression.png)
#
# ### Best Params for Decision Tree model
#
# - {'classifier__max_depth': 5, 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 2, 'feature_selection__k': 7, 'pca__n_components': 4}
#
# ### ROC Curve
#
# ### Decision Tree
#
# ![ROC Curve for Decision Tree](../reports/figures/roc_curve_Decision_Tree.png)
#
# ### Precision-Recall Curve
#
# ### Decision Tree
#
# ![Precision-Recall Curve for Decision Tree](../reports/figures/precision_recall_curve_Decision_Tree.png)
#
# ### Best Params for Random Forest model
#
# - {'classifier__max_depth': 3, 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 10, 'feature_selection__k': 8, 'pca__n_components': 4}
#
# ### ROC Curve
#
# ### Random Forest
#
# ![ROC Curve for Random Forest](../reports/figures/roc_curve_Random_Forest.png)
#
# ### Precision-Recall Curve
#
# ### Random Forest
#
# ![Precision-Recall Curve for Random Forest](../reports/figures/precision_recall_curve_Random_Forest.png)
#
# ### Best Params for SVM model
#
# - {'classifier__C': 1, 'classifier__degree': 3, 'classifier__kernel': 'linear', 'feature_selection__k': 7, 'pca__n_components': 5}
#
# ### ROC Curve
#
# ### SVM
#
# ![ROC Curve for SVM](../reports/figures/roc_curve_SVM.png)
#
# ### Precision-Recall Curve
#
# ### SVM
#
# ![Precision-Recall Curve for SVM](../reports/figures/precision_recall_curve_SVM.png)
#
# ### Best Params for Naive Bayes model
#
# - {'feature_selection__k': 7, 'pca__n_components': 3}
#
# ### ROC Curve
#
# ### Naive Bayes
#
# ![ROC Curve for Naive Bayes](../reports/figures/roc_curve_Naive_Bayes.png)
#
# ### Precision-Recall Curve
#
# ### Naive Bayes
#
# ![Precision-Recall Curve for Naive Bayes](../reports/figures/precision_recall_curve_Naive_Bayes.png)
#
# ### Best Params for KNN model
#
# - {'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'feature_selection__k': 7, 'pca__n_components': 4}
#
# ### ROC Curve
#
# ### KNN
#
# ![ROC Curve for KNN](../reports/figures/roc_curve_KNN.png)
#
# ### Precision-Recall Curve
#
# ### KNN
#
# ![Precision-Recall Curve for KNN](../reports/figures/precision_recall_curve_KNN.png)
#
# ### Best Params for AdaBoost model
#
# - {'classifier__learning_rate': 1, 'classifier__n_estimators': 20, 'feature_selection__k': 7, 'pca__n_components': 4}
#
# ### ROC Curve
#
# ### AdaBoost
#
# ![ROC Curve for AdaBoost](../reports/figures/roc_curve_AdaBoost.png)
#
# ### Precision-Recall Curve
#
# ### AdaBoost
#
# ![Precision-Recall Curve for AdaBoost](../reports/figures/precision_recall_curve_AdaBoost.png)
#
# ### Best Params for Gradient Boosting model
#
# - {'classifier__learning_rate': 1, 'classifier__n_estimators': 20, 'feature_selection__k': 7, 'pca__n_components': 6}
#
# ### ROC Curve
#
# ### Gradient Boosting
#
# ![ROC Curve for Gradient Boosting](../reports/figures/roc_curve_Gradient_Boosting.png)
#
# ### Precision-Recall Curve
#
# ### Gradient Boosting
#
# ![Precision-Recall Curve for Gradient Boosting](../reports/figures/precision_recall_curve_Gradient_Boosting.png)
#
# ### Best Params for XGBoost model
#
# - {'classifier__learning_rate': 0.2, 'classifier__max_depth': 5, 'classifier__n_estimators': 20, 'feature_selection__k': 7, 'pca__n_components': 5}
#
# ### ROC Curve
#
# ### XGBoost
#
# ![ROC Curve for XGBoost](../reports/figures/roc_curve_XGBoost.png)
#
# ### Precision-Recall Curve
#
# ### XGBoost
#
# ![Precision-Recall Curve for XGBoost](../reports/figures/precision_recall_curve_XGBoost.png)
